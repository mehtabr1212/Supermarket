# %%
import pandas as pd

# Read the uploaded CSV file into a DataFrame
df = pd.read_csv('data.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
null_values = df.isnull().sum()

print("Null values in the DataFrame:")
print(null_values)
#This code will print out the number of null values for each column in your DataFrame. If a column has no null values, the count will be zero.
# Out:
# Null values in the DataFrame:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %%
df['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
df['gross income'].value_counts()
# Out:
# 10.3260    2
# 4.4640     2
# 4.1540     2
# 9.0045     2
# 22.4280    2
#           ..
# 7.2135     1
# 19.5895    1
# 26.9150    1
# 24.2575    1
# 30.9190    1
# Name: gross income, Length: 990, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %% [markdown]
# df['column_name'].unique() returns an array of unique values in a specific column. df['column_name'].nunique() returns the number of unique values in a specific column.

# %%
df['Product line'].unique()
print(df['Product line'].unique())
df['Product line'].nunique()
# Out:
# ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
# 6

# %% [markdown]
# df.corr() computes the correlation between all numerical columns in the DataFrame. It's useful to understand relationships between variables.

# %% [markdown]
# groupby():
#
# df.groupby('column_name').mean() allows you to group data based on a column and then apply an aggregation function (e.g., mean, sum, etc.) to the groups.

# %%
df.groupby('Product line').mean()
# Out:
# <ipython-input-30-f629a62e4200>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product line').mean()
#                         Unit price  Quantity     Tax 5%       Total  \
# Product line
# Electronic accessories   53.551588  5.711765  15.220597  319.632538
# Fashion accessories      57.153652  5.067416  14.528062  305.089298
# Food and beverages       56.008851  5.471264  15.365310  322.671517
# Health and beauty        54.854474  5.618421  15.411572  323.643020
# Home and lifestyle       55.316937  5.693750  16.030331  336.636956
# Sports and travel        56.993253  5.542169  15.812630  332.065220
#
#                               cogs  gross margin percentage  gross income  \
# Product line
# Electronic accessories  304.411941                 4.761905     15.220597
# Fashion accessories     290.561236                 4.761905     14.528062
# Food and beverages      307.306207                 4.761905     15.365310
# Health and beauty       308.231447                 4.761905     15.411572
# Home and lifestyle      320.606625                 4.761905     16.030331
# Sports and travel       316.252590                 4.761905     15.812630
#
#                           Rating
# Product line
# Electronic accessories  6.924706
# Fashion accessories     7.029213
# Food and beverages      7.113218
# Health and beauty       7.003289
# Home and lifestyle      6.837500
# Sports and travel       6.916265

# %%
pd.pivot_table(df, values='Total', index='Quantity', columns='Product line', aggfunc='mean')
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Quantity
# 1                          66.511200            47.674550           56.546000
# 2                         103.306875           155.198591          132.376125
# 3                         170.985938           194.494500          162.798848
# 4                         209.221895           228.148000          250.849667
# 5                         223.887794           285.236000          286.702500
# 6                         303.998211           342.704250          381.724412
# 7                         466.403437           451.895500          322.622125
# 8                         427.886118           471.135000          424.849600
# 9                         536.889937           551.421000          512.673618
# 10                        570.956591           574.465000          672.462000
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Quantity
# 1                     58.320500           60.792577          61.504579
# 2                    102.055154           86.584500         116.503333
# 3                    192.196038          195.782192         166.809682
# 4                    246.066800          213.360000         255.813000
# 5                    236.906250          288.281538         274.114167
# 6                    388.296000          348.594000         352.193211
# 7                    445.549263          421.461250         423.543750
# 8                    415.066400          579.861882         548.025333
# 9                    508.475423          434.784000         665.826750
# 10                   576.505588          635.935588         511.063636

# %%
df.sort_values('gross income', ascending=False)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 350       99.30        10  49.6500  1042.6500  2/15/2019  14:53  Credit card
# 167       98.98        10  49.4900  1039.2900   2/8/2019  16:20  Credit card
# 557       98.52        10  49.2600  1034.4600  1/30/2019  20:23      Ewallet
# 699       97.50        10  48.7500  1023.7500  1/12/2019  16:18      Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet
# ..          ...       ...      ...        ...        ...    ...          ...
# 402       13.98         1   0.6990    14.6790   2/4/2019  13:38      Ewallet
# 443       12.78         1   0.6390    13.4190   1/8/2019  14:11      Ewallet
# 223       12.54         1   0.6270    13.1670  2/21/2019  12:38         Cash
# 629       12.09         1   0.6045    12.6945  1/26/2019  18:19  Credit card
# 822       10.17         1   0.5085    10.6785   2/7/2019  14:15         Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 350  993.00                 4.761905       49.6500     6.6
# 167  989.80                 4.761905       49.4900     8.7
# 557  985.20                 4.761905       49.2600     4.5
# 699  975.00                 4.761905       48.7500     8.0
# 996  973.80                 4.761905       48.6900     4.4
# ..      ...                      ...           ...     ...
# 402   13.98                 4.761905        0.6990     9.8
# 443   12.78                 4.761905        0.6390     9.5
# 223   12.54                 4.761905        0.6270     8.2
# 629   12.09                 4.761905        0.6045     8.2
# 822   10.17                 4.761905        0.5085     5.9
#
# [1000 rows x 17 columns]

# %% [markdown]
# Univariate Analysis:
#
# Univariate analysis involves examining a single variable in isolation. It helps in understanding the distribution, central tendency, and variability of the variable. Common techniques include:

# %% [markdown]
# ## Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Extract the gross income scores
data_viz_scores = df['Quantity']

# Descriptive statistics
mean = data_viz_scores.mean()
median = data_viz_scores.median()
mode = data_viz_scores.mode()[0]
std_dev = data_viz_scores.std()

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Standard Deviation: {std_dev}")


import matplotlib.pyplot as plt
import seaborn as sns

# Generate a count plot for Data Visualization scores
plt.figure(figsize=(10, 6))
sns.countplot(x=df['Quantity'], color='skyblue')
plt.title("Quantity Scores Count Plot")
plt.xlabel("Quantity Scores")
plt.ylabel("Count")
plt.show()

# Generate a histogram
plt.figure(figsize=(10, 6))
plt.hist(data_viz_scores, bins=6, color='skyblue', edgecolor='black')
plt.title("Quantity Scores")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 5.51
# Median: 5.0
# Mode: 10
# Standard Deviation: 2.923430595455696

# %% [markdown]
# Conclusion : Descriptive Statistics:
#
# Mean: The average score in Data Visualization is approximately 15.16.
#
# Median: The middle value (50th percentile) of the scores is approximately 12.0.
#
# Mode: The most frequently occurring score is 10.
#
# Standard Deviation: The standard deviation of the scores is approximately 9.8, indicating a moderate amount of variability.
#
# Count Plot:
#
# The count plot of Data Visualization scores provides a clear count of how many students received each score. It shows that the highest count is around the score of 10.
#
# Histogram:
#
# The histogram of Data Visualization scores shows that the majority of students' scores are concentrated around the middle range (4 to 7). There are four bins in the histogram, indicating that the scores are divided into four intervals.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# Bivariate Analysis:
#
# Bivariate analysis involves the analysis of two variables simultaneously to understand the relationship between them.

# %%
# Scatter Plot between Quantity and Product line scores
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Quantity', y='Product line',hue="Gender", data=df, color='red')
plt.title("Scatter Plot: Quantity vs Product line")
plt.xlabel("Quantity Scores")
plt.ylabel("Product line Scores")
plt.show()

# %%
# Scatter Plot between City and Product line scores
plt.figure(figsize=(8, 6))
sns.swarmplot(x='Branch',y="Gender", hue='Quantity', data=df, palette='light:green')
plt.title("Swarm Plot: Branch: Gender")
plt.xlabel("Branch")
plt.ylabel("Gender")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 81.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 81.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 81.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 86.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 86.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Generate a bar plot with hue ()
plt.figure(figsize=(10, 6))
sns.barplot(x='City',y="gross income", hue='Product line', data=df, ci=None, palette='Set2')
plt.title("Distribution of City with gross income")
plt.xlabel("City")
plt.ylabel("Gross Income")
plt.show()
# Out:
# <ipython-input-52-99aaef817137>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='City',y="gross income", hue='Product line', data=df, ci=None, palette='Set2')

# %%
df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = df[['Rating', 'Tax 5%', 'gross income', 'Quantity', 'Total']].corr()

# Generate a heatmap
plt.figure(figsize=(9, 7))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# A heatmap is a graphical representation of data in a matrix format, where values are represented by different colors. It is particularly useful for visualizing relationships and patterns in complex datasets. In the context of a correlation matrix heatmap:
#
# Color Gradient:
#
# The heatmap uses a color gradient to represent the values in the matrix. Typically, a gradient of colors ranging from cool (e.g., blue) to warm (e.g., red) is used.
# In a correlation matrix, cooler colors (shades of blue) represent lower or negative correlations, while warmer colors (shades of red) represent higher or positive correlations.
# Correlation Values:
#
# Each cell in the matrix represents the correlation coefficient between two variables. This value ranges from -1 to 1, where:
# 1 indicates a perfect positive correlation (as one variable increases, the other also increases proportionally).
# -1 indicates a perfect negative correlation (as one variable increases, the other decreases proportionally).
# 0 indicates no linear correlation between the variables.
# Annotations:
#
# Annotations are usually included within each cell to display the exact correlation coefficient. These values provide quantitative information about the strength and direction of the relationship.
# Diagonal Line:
#
# The diagonal line in the heatmap (from top-left to bottom-right) represents the correlation of each variable with itself, which is always 1.
# Interpretation:
#
# A positive correlation (closer to 1) between two variables suggests that they tend to increase or decrease together. For example, if one subject's score increases, the other subject's score is also likely to increase.
#
# A negative correlation (closer to -1) suggests an inverse relationship. As one variable increases, the other tends to decrease.
#
# A correlation close to 0 indicates a weak or no linear relationship between the variables.
#
# A correlation of 1 or -1 indicates a perfect linear relationship.
#
# The strength and direction of correlation can be useful in understanding how variables interact with each other.
#
# Remember, correlation does not imply causation. Even if two variables are highly correlated, it doesn't necessarily mean that one causes the other to change. Other factors may be involved.
#
# In summary, a heatmap of a correlation matrix helps to visually identify relationships and patterns in a dataset, making it a valuable tool for exploratory data analysis.

# %%
# Assuming `df` is your DataFrame
# For example, if you generated the DataFrame as per the previous conversation:
# df = ... (previous code)

# Calculate variance of each subject
variance = df.var()
print("Variance:")
print(variance)

# Calculate the covariance matrix
covariance_matrix = df.cov()
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Variance:
# Unit price                   701.965331
# Quantity                       8.546446
# Tax 5%                       137.096594
# Total                      60459.598018
# cogs                       54838.637658
# gross margin percentage        0.000000
# gross income                 137.096594
# Rating                         2.953518
# dtype: float64
#
# Covariance Matrix:
#                           Unit price    Quantity       Tax 5%         Total  \
# Unit price                701.965331    0.834778   196.668340   4130.035142
# Quantity                    0.834778    8.546446    24.149570    507.140978
# Tax 5%                    196.668340   24.149570   137.096594   2879.028477
# Total                    4130.035142  507.140978  2879.028477  60459.598018
# cogs                     3933.366802  482.991408  2741.931883  57580.569541
# gross margin percentage     0.000000    0.000000     0.000000      0.000000
# gross income              196.668340   24.149570   137.096594   2879.028477
# Rating                     -0.399668   -0.079456    -0.733300    -15.399306
#
#                                  cogs  gross margin percentage  gross income  \
# Unit price                3933.366802                      0.0    196.668340
# Quantity                   482.991408                      0.0     24.149570
# Tax 5%                    2741.931883                      0.0    137.096594
# Total                    57580.569541                      0.0   2879.028477
# cogs                     54838.637658                      0.0   2741.931883
# gross margin percentage      0.000000                      0.0      0.000000
# gross income              2741.931883                      0.0    137.096594
# Rating                     -14.666006                      0.0     -0.733300
#
#                             Rating
# Unit price               -0.399668
# Quantity                 -0.079456
# Tax 5%                   -0.733300
# Total                   -15.399306
# cogs                    -14.666006
# gross margin percentage   0.000000
# gross income             -0.733300
# Rating                    2.953518
# <ipython-input-62-f2a9cb6946ca>:6: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   variance = df.var()
# <ipython-input-62-f2a9cb6946ca>:11: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   covariance_matrix = df.cov()

# %%
# Assuming `df` is your DataFrame
# For example, if you generated the DataFrame as per the previous conversation:
# df = ... (previous code)

# Separate DataFrame based on divisions
division_A = df[df['Branch'] == 'A']

division_B = df[df['Branch'] == 'B']


division_C = df[df['Branch'] == 'C']

# Display the first few rows of each division
print("Branch A:")
print(division_A)

print("\nBranch B:")
print(division_B.head())

print("\nBranch C:")
print(division_C.head())
# Out:
# Branch A:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0         74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 2         46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3         58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4         86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
# 6         68.84         6  20.6520  433.6920  2/25/2019  14:36      Ewallet
# ..          ...       ...      ...       ...        ...    ...          ...
# 990       56.56         5  14.1400  296.9400  3/22/2019  19:06  Credit card
# 992       58.03         2   5.8030  121.8630  3/10/2019  20:46      Ewallet
# 997       31.84         1   1.5920   33.4320   2/9/2019  13:22         Cash
# 998       65.82         1   3.2910   69.1110  2/22/2019  15:33         Cash
# 999       88.34         7  30.9190  649.2990  2/18/2019  13:28         Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 0    522.83                 4.761905       26.1415     9.1
# 2    324.31                 4.761905       16.2155     7.4
# 3    465.76                 4.761905       23.2880     8.4
# 4    604.17                 4.761905       30.2085     5.3
# 6    413.04                 4.761905       20.6520     5.8
# ..      ...                      ...           ...     ...
# 990  282.80                 4.761905       14.1400     4.5
# 992  116.06                 4.761905        5.8030     8.8
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6
#
# [340 rows x 17 columns]
#
# Branch B:
#      Invoice ID Branch      City Customer type  Gender  \
# 9   692-92-5582      B  Mandalay        Member  Female
# 10  351-62-0822      B  Mandalay        Member  Female
# 11  529-56-3974      B  Mandalay        Member    Male
# 15  299-46-1805      B  Mandalay        Member  Female
# 19  319-50-3348      B  Mandalay        Normal  Female
#
#               Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 9       Food and beverages       54.84         3   8.226  172.746  2/20/2019
# 10     Fashion accessories       14.48         4   2.896   60.816   2/6/2019
# 11  Electronic accessories       25.51         4   5.102  107.142   3/9/2019
# 15       Sports and travel       93.72         6  28.116  590.436  1/15/2019
# 19      Home and lifestyle       40.30         2   4.030   84.630  3/11/2019
#
#      Time      Payment    cogs  gross margin percentage  gross income  Rating
# 9   13:27  Credit card  164.52                 4.761905         8.226     5.9
# 10  18:07      Ewallet   57.92                 4.761905         2.896     4.5
# 11  17:03         Cash  102.04                 4.761905         5.102     6.8
# 15  16:19         Cash  562.32                 4.761905        28.116     4.5
# 19  15:30      Ewallet   80.60                 4.761905         4.030     4.4
#
# Branch C:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 20  300-71-4605      C  Naypyitaw        Member    Male
# 34  183-56-6882      C  Naypyitaw        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 1   Electronic accessories       15.28         5   3.8200   80.2200
# 5   Electronic accessories       85.39         7  29.8865  627.6165
# 7       Home and lifestyle       73.56        10  36.7800  772.3800
# 20  Electronic accessories       86.04         5  21.5100  451.7100
# 34      Food and beverages       99.42         4  19.8840  417.5640
#
#          Date   Time  Payment    cogs  gross margin percentage  gross income  \
# 1    3/8/2019  10:29     Cash   76.40                 4.761905        3.8200
# 5   3/25/2019  18:30  Ewallet  597.73                 4.761905       29.8865
# 7   2/24/2019  11:38  Ewallet  735.60                 4.761905       36.7800
# 20  2/25/2019  11:24  Ewallet  430.20                 4.761905       21.5100
# 34   2/6/2019  10:42  Ewallet  397.68                 4.761905       19.8840
#
#     Rating
# 1      9.6
# 5      4.1
# 7      8.0
# 20     4.8
# 34     7.5

# %% [markdown]
# Avoid this kind of pie chart , apply data manipulation to get clear pie chart

# %%
division_A.value_counts('Rating')
# Out:
# Rating
# 4.2     11
# 6.6     11
# 7.4      9
# 9.8      8
# 6.2      8
#         ..
# 8.1      3
# 4.0      2
# 6.3      2
# 5.3      2
# 10.0     1
# Length: 61, dtype: int64

# %% [markdown]
# ## Multivariate Analysis:

# %% [markdown]
# Multivariate Analysis:
#
# Multivariate analysis involves the analysis of three or more variables to understand complex relationships.

# %%
# Pair Plot for Data Visualization, Data Structures, Python, Maths, and ADBMS
sns.pairplot(df[['Rating', 'cogs', 'gross income', 'Quantity', 'Total']], diag_kind='kde')
plt.suptitle("Pair Plots", y=1.02)
plt.show()
